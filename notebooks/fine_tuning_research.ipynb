# %% [markdown]
# # Launch SFT jobs in the Notebook.
# <a target="_blank" href="https://colab.research.google.com/github/ai-hero/llm-research-orchestration/blob/main/notebooks/fine_tuning_research.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !pip install -v git+https://github.com/ai-hero/llm-research-fine-tuning@main
# Out:
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Collecting git+https://github.com/shankarg87/training_research@main
#   Cloning https://github.com/shankarg87/training_research (to revision main) to /tmp/pip-req-build-2bzua9w2
#   Running command git version
#   git version 2.34.1
#   Running command git clone --filter=blob:none https://github.com/shankarg87/training_research /tmp/pip-req-build-2bzua9w2
#   Cloning into '/tmp/pip-req-build-2bzua9w2'...
#   Running command git show-ref main
#   916ce585a64990211c4f40e2875529013e3fd229 refs/heads/main
#   916ce585a64990211c4f40e2875529013e3fd229 refs/remotes/origin/main
#   Running command git symbolic-ref -q HEAD
#   refs/heads/main
#   Resolved https://github.com/shankarg87/training_research to commit 916ce585a64990211c4f40e2875529013e3fd229
#   Running command git rev-parse HEAD
#   916ce585a64990211c4f40e2875529013e3fd229
#   Running command pip subprocess to install build dependencies
#   Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
#   Collecting setuptools>=40.8.0
#     Downloading setuptools-69.1.0-py3-none-any.whl (819 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 14.6 MB/s eta 0:00:00
#   Collecting wheel
#     Downloading wheel-0.42.0-py3-none-any.whl (65 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 8.6 MB/s eta 0:00:00
#   Installing collected packages: wheel, setuptools
#     Creating /tmp/pip-build-env-ldbjxblq/overlay/local/bin
#     changing mode of /tmp/pip-build-env-ldbjxblq/overlay/local/bin/wheel to 755
#   ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
#   ipython 7.34.0 requires jedi>=0.16, which is not installed.
#   lida 0.0.10 requires fastapi, which is not installed.
#   lida 0.0.10 requires kaleido, which is not installed.
#   lida 0.0.10 requires python-multipart, which is not installed.
#   lida 0.0.10 requires uvicorn, which is not installed.
#   Successfully installed setuptools-69.1.0 wheel-0.42.0
#   Installing build dependencies ... done
#   Running command Getting requirements to build wheel
#   running egg_info
#   creating src/finetuningresearch.egg-info
#   writing src/finetuningresearch.egg-info/PKG-INFO
#   writing dependency_links to src/finetuningresearch.egg-info/dependency_links.txt
#   writing requirements to src/finetuningresearch.egg-info/requires.txt
#   writing top-level names to src/finetuningresearch.egg-info/top_level.txt
#   writing manifest file 'src/finetuningresearch.egg-info/SOURCES.txt'
#   reading manifest file 'src/finetuningresearch.egg-info/SOURCES.txt'
#   adding license file 'LICENSE'
#   writing manifest file 'src/finetuningresearch.egg-info/SOURCES.txt'
#   Getting requirements to build wheel ... done
#   Running command Preparing metadata (pyproject.toml)
#   running dist_info
#   creating /tmp/pip-modern-metadata-6lzlru2j/finetuningresearch.egg-info
#   writing /tmp/pip-modern-metadata-6lzlru2j/finetuningresearch.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-modern-metadata-6lzlru2j/finetuningresearch.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-modern-metadata-6lzlru2j/finetuningresearch.egg-info/requires.txt
#   writing top-level names to /tmp/pip-modern-metadata-6lzlru2j/finetuningresearch.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-modern-metadata-6lzlru2j/finetuningresearch.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-modern-metadata-6lzlru2j/finetuningresearch.egg-info/SOURCES.txt'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-modern-metadata-6lzlru2j/finetuningresearch.egg-info/SOURCES.txt'
#   creating '/tmp/pip-modern-metadata-6lzlru2j/finetuningresearch-0.1.0.dist-info'
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers>=4.35.0 in /usr/local/lib/python3.10/dist-packages (from finetuningresearch==0.1.0) (4.35.2)
# Collecting peft>=0.5.0 (from finetuningresearch==0.1.0)
#   Downloading peft-0.8.2-py3-none-any.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 3.1 MB/s eta 0:00:00
# Collecting bitsandbytes>=0.41.1 (from finetuningresearch==0.1.0)
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 14.9 MB/s eta 0:00:00
# Collecting accelerate>=0.25.0 (from finetuningresearch==0.1.0)
#   Downloading accelerate-0.27.0-py3-none-any.whl (279 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.7/279.7 kB 29.8 MB/s eta 0:00:00
# Collecting trl>=0.7.2 (from finetuningresearch==0.1.0)
#   Downloading trl-0.7.10-py3-none-any.whl (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.9/150.9 kB 18.4 MB/s eta 0:00:00
# Collecting pydantic-settings>=2.0.3 (from finetuningresearch==0.1.0)
#   Downloading pydantic_settings-2.1.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: scipy>=1.11.3 in /usr/local/lib/python3.10/dist-packages (from finetuningresearch==0.1.0) (1.11.4)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from finetuningresearch==0.1.0) (6.0.1)
# Collecting datasets>=2.14.6 (from finetuningresearch==0.1.0)
#   Downloading datasets-2.17.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 44.5 MB/s eta 0:00:00
# Collecting einops>=0.7.0 (from finetuningresearch==0.1.0)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.1 MB/s eta 0:00:00
# Collecting wandb>=0.15.12 (from finetuningresearch==0.1.0)
#   Downloading wandb-0.16.3-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 81.2 MB/s eta 0:00:00
# Collecting python-dotenv (from finetuningresearch==0.1.0)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting minio>=7.2.0 (from finetuningresearch==0.1.0)
#   Downloading minio-7.2.4-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 kB 12.2 MB/s eta 0:00:00
# Collecting fire (from finetuningresearch==0.1.0)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 10.4 MB/s eta 0:00:00
#   Running command python setup.py egg_info
#   /usr/local/lib/python3.10/dist-packages/setuptools/dist.py:755: SetuptoolsDeprecationWarning: Invalid dash-separated options
#   !!
#
#           ********************************************************************************
#           Usage of dash-separated 'license-file' will not be supported in future
#           versions. Please use the underscore name 'license_file' instead.
#
#           This deprecation is overdue, please update your project and remove deprecated
#           calls to avoid build errors in the future.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     opt = self.warn_dash_deprecation(opt, section)
#   /usr/local/lib/python3.10/dist-packages/setuptools/config/setupcfg.py:293: _DeprecatedConfig: Deprecated config in `setup.cfg`
#   !!
#
#           ********************************************************************************
#           The license_file parameter is deprecated, use license_files instead.
#
#           This deprecation is overdue, please update your project and remove deprecated
#           calls to avoid build errors in the future.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     parsed = self.parsers.get(option_name, lambda x: x)(value)
#   running egg_info
#   creating /tmp/pip-pip-egg-info-fyvvgwkt/fire.egg-info
#   writing /tmp/pip-pip-egg-info-fyvvgwkt/fire.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-fyvvgwkt/fire.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-fyvvgwkt/fire.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-fyvvgwkt/fire.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-fyvvgwkt/fire.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-fyvvgwkt/fire.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-pip-egg-info-fyvvgwkt/fire.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Collecting types-PyYAML (from finetuningresearch==0.1.0)
#   Downloading types_PyYAML-6.0.12.12-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.25.0->finetuningresearch==0.1.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.25.0->finetuningresearch==0.1.0) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.25.0->finetuningresearch==0.1.0) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.25.0->finetuningresearch==0.1.0) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.25.0->finetuningresearch==0.1.0) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.25.0->finetuningresearch==0.1.0) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.6->finetuningresearch==0.1.0) (3.13.1)
# Collecting pyarrow>=12.0.0 (from datasets>=2.14.6->finetuningresearch==0.1.0)
#   Downloading pyarrow-15.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (38.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 43.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.6->finetuningresearch==0.1.0) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.14.6->finetuningresearch==0.1.0)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.6->finetuningresearch==0.1.0) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.6->finetuningresearch==0.1.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.6->finetuningresearch==0.1.0) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.6->finetuningresearch==0.1.0) (3.4.1)
# Collecting multiprocess (from datasets>=2.14.6->finetuningresearch==0.1.0)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.6->finetuningresearch==0.1.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.6->finetuningresearch==0.1.0) (3.9.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from minio>=7.2.0->finetuningresearch==0.1.0) (2024.2.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from minio>=7.2.0->finetuningresearch==0.1.0) (2.0.7)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from minio>=7.2.0->finetuningresearch==0.1.0) (23.1.0)
# Collecting pycryptodome (from minio>=7.2.0->finetuningresearch==0.1.0)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 83.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from minio>=7.2.0->finetuningresearch==0.1.0) (4.9.0)
# Requirement already satisfied: pydantic>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings>=2.0.3->finetuningresearch==0.1.0) (2.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->finetuningresearch==0.1.0) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->finetuningresearch==0.1.0) (0.15.1)
# Collecting tyro>=0.5.11 (from trl>=0.7.2->finetuningresearch==0.1.0)
#   Downloading tyro-0.7.2-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.15.12->finetuningresearch==0.1.0) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb>=0.15.12->finetuningresearch==0.1.0)
#   Downloading GitPython-3.1.41-py3-none-any.whl (196 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 21.6 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.15.12->finetuningresearch==0.1.0)
#   Downloading sentry_sdk-1.40.3-py2.py3-none-any.whl (257 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.8/257.8 kB 26.4 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.15.12->finetuningresearch==0.1.0)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle (from wandb>=0.15.12->finetuningresearch==0.1.0)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb>=0.15.12->finetuningresearch==0.1.0) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.15.12->finetuningresearch==0.1.0) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.15.12->finetuningresearch==0.1.0) (3.20.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire->finetuningresearch==0.1.0) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->finetuningresearch==0.1.0) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.6->finetuningresearch==0.1.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.6->finetuningresearch==0.1.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.6->finetuningresearch==0.1.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.6->finetuningresearch==0.1.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.6->finetuningresearch==0.1.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.6->finetuningresearch==0.1.0) (4.0.3)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb>=0.15.12->finetuningresearch==0.1.0)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.3.0->pydantic-settings>=2.0.3->finetuningresearch==0.1.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.3.0->pydantic-settings>=2.0.3->finetuningresearch==0.1.0) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.14.6->finetuningresearch==0.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.14.6->finetuningresearch==0.1.0) (3.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.25.0->finetuningresearch==0.1.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.25.0->finetuningresearch==0.1.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.25.0->finetuningresearch==0.1.0) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.25.0->finetuningresearch==0.1.0) (2.1.0)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl>=0.7.2->finetuningresearch==0.1.0)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl>=0.7.2->finetuningresearch==0.1.0) (13.7.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl>=0.7.2->finetuningresearch==0.1.0)
#   Downloading shtab-1.6.5-py3-none-any.whl (13 kB)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->minio>=7.2.0->finetuningresearch==0.1.0) (21.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.14.6->finetuningresearch==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.14.6->finetuningresearch==0.1.0) (2023.4)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb>=0.15.12->finetuningresearch==0.1.0)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl>=0.7.2->finetuningresearch==0.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl>=0.7.2->finetuningresearch==0.1.0) (2.16.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->minio>=7.2.0->finetuningresearch==0.1.0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate>=0.25.0->finetuningresearch==0.1.0) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate>=0.25.0->finetuningresearch==0.1.0) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio>=7.2.0->finetuningresearch==0.1.0) (2.21)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl>=0.7.2->finetuningresearch==0.1.0) (0.1.2)
# Building wheels for collected packages: finetuningresearch, fire
#   Running command git rev-parse HEAD
#   916ce585a64990211c4f40e2875529013e3fd229
#   Running command Building wheel for finetuningresearch (pyproject.toml)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   creating build/lib/finetuningresearch
#   copying src/finetuningresearch/__init__.py -> build/lib/finetuningresearch
#   copying src/finetuningresearch/utils.py -> build/lib/finetuningresearch
#   copying src/finetuningresearch/sft.py -> build/lib/finetuningresearch
#   running egg_info
#   writing src/finetuningresearch.egg-info/PKG-INFO
#   writing dependency_links to src/finetuningresearch.egg-info/dependency_links.txt
#   writing requirements to src/finetuningresearch.egg-info/requires.txt
#   writing top-level names to src/finetuningresearch.egg-info/top_level.txt
#   reading manifest file 'src/finetuningresearch.egg-info/SOURCES.txt'
#   adding license file 'LICENSE'
#   writing manifest file 'src/finetuningresearch.egg-info/SOURCES.txt'
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/finetuningresearch
#   copying build/lib/finetuningresearch/__init__.py -> build/bdist.linux-x86_64/wheel/finetuningresearch
#   copying build/lib/finetuningresearch/utils.py -> build/bdist.linux-x86_64/wheel/finetuningresearch
#   copying build/lib/finetuningresearch/sft.py -> build/bdist.linux-x86_64/wheel/finetuningresearch
#   running install_egg_info
#   Copying src/finetuningresearch.egg-info to build/bdist.linux-x86_64/wheel/finetuningresearch-0.1.0-py3.10.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/finetuningresearch-0.1.0.dist-info/WHEEL
#   creating '/tmp/pip-wheel-1_ci2qb5/.tmp-s366koe_/finetuningresearch-0.1.0-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding 'finetuningresearch/__init__.py'
#   adding 'finetuningresearch/sft.py'
#   adding 'finetuningresearch/utils.py'
#   adding 'finetuningresearch-0.1.0.dist-info/LICENSE'
#   adding 'finetuningresearch-0.1.0.dist-info/METADATA'
#   adding 'finetuningresearch-0.1.0.dist-info/WHEEL'
#   adding 'finetuningresearch-0.1.0.dist-info/top_level.txt'
#   adding 'finetuningresearch-0.1.0.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for finetuningresearch (pyproject.toml) ... done
#   Created wheel for finetuningresearch: filename=finetuningresearch-0.1.0-py3-none-any.whl size=11351 sha256=0ba6664329ed1d8adaa7ba6a709fd9682a23226ebfa1e43b2c67d0659188cb08
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_58uhi8o/wheels/6e/c1/f1/591c56fccfd6f9869b48ae0ad0c07de2eaee6439065deb6fba
#   Running command python setup.py bdist_wheel
#   /usr/local/lib/python3.10/dist-packages/setuptools/dist.py:755: SetuptoolsDeprecationWarning: Invalid dash-separated options
#   !!
#
#           ********************************************************************************
#           Usage of dash-separated 'license-file' will not be supported in future
#           versions. Please use the underscore name 'license_file' instead.
#
#           This deprecation is overdue, please update your project and remove deprecated
#           calls to avoid build errors in the future.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     opt = self.warn_dash_deprecation(opt, section)
#   /usr/local/lib/python3.10/dist-packages/setuptools/config/setupcfg.py:293: _DeprecatedConfig: Deprecated config in `setup.cfg`
#   !!
#
#           ********************************************************************************
#           The license_file parameter is deprecated, use license_files instead.
#
#           This deprecation is overdue, please update your project and remove deprecated
#           calls to avoid build errors in the future.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     parsed = self.parsers.get(option_name, lambda x: x)(value)
#   running bdist_wheel
#   The [wheel] section is deprecated. Use [bdist_wheel] instead.
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   creating build/lib/fire
#   copying fire/formatting.py -> build/lib/fire
#   copying fire/decorators.py -> build/lib/fire
#   copying fire/completion_test.py -> build/lib/fire
#   copying fire/trace.py -> build/lib/fire
#   copying fire/fire_import_test.py -> build/lib/fire
#   copying fire/testutils.py -> build/lib/fire
#   copying fire/decorators_test.py -> build/lib/fire
#   copying fire/docstrings_test.py -> build/lib/fire
#   copying fire/docstrings_fuzz_test.py -> build/lib/fire
#   copying fire/trace_test.py -> build/lib/fire
#   copying fire/parser_fuzz_test.py -> build/lib/fire
#   copying fire/__main__.py -> build/lib/fire
#   copying fire/docstrings.py -> build/lib/fire
#   copying fire/custom_descriptions.py -> build/lib/fire
#   copying fire/__init__.py -> build/lib/fire
#   copying fire/parser_test.py -> build/lib/fire
#   copying fire/completion.py -> build/lib/fire
#   copying fire/helptext_test.py -> build/lib/fire
#   copying fire/core_test.py -> build/lib/fire
#   copying fire/formatting_test.py -> build/lib/fire
#   copying fire/core.py -> build/lib/fire
#   copying fire/interact_test.py -> build/lib/fire
#   copying fire/test_components.py -> build/lib/fire
#   copying fire/formatting_windows.py -> build/lib/fire
#   copying fire/interact.py -> build/lib/fire
#   copying fire/helptext.py -> build/lib/fire
#   copying fire/parser.py -> build/lib/fire
#   copying fire/inspectutils_test.py -> build/lib/fire
#   copying fire/fire_test.py -> build/lib/fire
#   copying fire/custom_descriptions_test.py -> build/lib/fire
#   copying fire/test_components_test.py -> build/lib/fire
#   copying fire/inspectutils.py -> build/lib/fire
#   copying fire/test_components_py3.py -> build/lib/fire
#   copying fire/test_components_bin.py -> build/lib/fire
#   copying fire/main_test.py -> build/lib/fire
#   copying fire/testutils_test.py -> build/lib/fire
#   copying fire/value_types.py -> build/lib/fire
#   creating build/lib/fire/console
#   copying fire/console/platforms.py -> build/lib/fire/console
#   copying fire/console/files.py -> build/lib/fire/console
#   copying fire/console/__init__.py -> build/lib/fire/console
#   copying fire/console/encoding.py -> build/lib/fire/console
#   copying fire/console/console_attr_os.py -> build/lib/fire/console
#   copying fire/console/text.py -> build/lib/fire/console
#   copying fire/console/console_attr.py -> build/lib/fire/console
#   copying fire/console/console_io.py -> build/lib/fire/console
#   copying fire/console/console_pager.py -> build/lib/fire/console
#   /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#   !!
#
#           ********************************************************************************
#           Please avoid running ``setup.py`` directly.
#           Instead, use pypa/build, pypa/installer, pypa/build or
#           other standards-based tools.
#
#           See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#           ********************************************************************************
#
#   !!
#     self.initialize_options()
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/formatting.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/decorators.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/completion_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/trace.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/fire_import_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/testutils.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/decorators_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/docstrings_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/docstrings_fuzz_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/trace_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/parser_fuzz_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/__main__.py -> build/bdist.linux-x86_64/wheel/fire
#   creating build/bdist.linux-x86_64/wheel/fire/console
#   copying build/lib/fire/console/platforms.py -> build/bdist.linux-x86_64/wheel/fire/console
#   copying build/lib/fire/console/files.py -> build/bdist.linux-x86_64/wheel/fire/console
#   copying build/lib/fire/console/__init__.py -> build/bdist.linux-x86_64/wheel/fire/console
#   copying build/lib/fire/console/encoding.py -> build/bdist.linux-x86_64/wheel/fire/console
#   copying build/lib/fire/console/console_attr_os.py -> build/bdist.linux-x86_64/wheel/fire/console
#   copying build/lib/fire/console/text.py -> build/bdist.linux-x86_64/wheel/fire/console
#   copying build/lib/fire/console/console_attr.py -> build/bdist.linux-x86_64/wheel/fire/console
#   copying build/lib/fire/console/console_io.py -> build/bdist.linux-x86_64/wheel/fire/console
#   copying build/lib/fire/console/console_pager.py -> build/bdist.linux-x86_64/wheel/fire/console
#   copying build/lib/fire/docstrings.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/custom_descriptions.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/__init__.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/parser_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/completion.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/helptext_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/core_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/formatting_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/core.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/interact_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/test_components.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/formatting_windows.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/interact.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/helptext.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/parser.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/inspectutils_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/fire_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/custom_descriptions_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/test_components_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/inspectutils.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/test_components_py3.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/test_components_bin.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/main_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/testutils_test.py -> build/bdist.linux-x86_64/wheel/fire
#   copying build/lib/fire/value_types.py -> build/bdist.linux-x86_64/wheel/fire
#   running install_egg_info
#   running egg_info
#   writing fire.egg-info/PKG-INFO
#   writing dependency_links to fire.egg-info/dependency_links.txt
#   writing requirements to fire.egg-info/requires.txt
#   writing top-level names to fire.egg-info/top_level.txt
#   reading manifest file 'fire.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE'
#   writing manifest file 'fire.egg-info/SOURCES.txt'
#   Copying fire.egg-info to build/bdist.linux-x86_64/wheel/fire-0.5.0-py3.10.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/fire-0.5.0.dist-info/WHEEL
#   creating '/tmp/pip-wheel-lpvatbkb/fire-0.5.0-py2.py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding 'fire/__init__.py'
#   adding 'fire/__main__.py'
#   adding 'fire/completion.py'
#   adding 'fire/completion_test.py'
#   adding 'fire/core.py'
#   adding 'fire/core_test.py'
#   adding 'fire/custom_descriptions.py'
#   adding 'fire/custom_descriptions_test.py'
#   adding 'fire/decorators.py'
#   adding 'fire/decorators_test.py'
#   adding 'fire/docstrings.py'
#   adding 'fire/docstrings_fuzz_test.py'
#   adding 'fire/docstrings_test.py'
#   adding 'fire/fire_import_test.py'
#   adding 'fire/fire_test.py'
#   adding 'fire/formatting.py'
#   adding 'fire/formatting_test.py'
#   adding 'fire/formatting_windows.py'
#   adding 'fire/helptext.py'
#   adding 'fire/helptext_test.py'
#   adding 'fire/inspectutils.py'
#   adding 'fire/inspectutils_test.py'
#   adding 'fire/interact.py'
#   adding 'fire/interact_test.py'
#   adding 'fire/main_test.py'
#   adding 'fire/parser.py'
#   adding 'fire/parser_fuzz_test.py'
#   adding 'fire/parser_test.py'
#   adding 'fire/test_components.py'
#   adding 'fire/test_components_bin.py'
#   adding 'fire/test_components_py3.py'
#   adding 'fire/test_components_test.py'
#   adding 'fire/testutils.py'
#   adding 'fire/testutils_test.py'
#   adding 'fire/trace.py'
#   adding 'fire/trace_test.py'
#   adding 'fire/value_types.py'
#   adding 'fire/console/__init__.py'
#   adding 'fire/console/console_attr.py'
#   adding 'fire/console/console_attr_os.py'
#   adding 'fire/console/console_io.py'
#   adding 'fire/console/console_pager.py'
#   adding 'fire/console/encoding.py'
#   adding 'fire/console/files.py'
#   adding 'fire/console/platforms.py'
#   adding 'fire/console/text.py'
#   adding 'fire-0.5.0.dist-info/LICENSE'
#   adding 'fire-0.5.0.dist-info/METADATA'
#   adding 'fire-0.5.0.dist-info/WHEEL'
#   adding 'fire-0.5.0.dist-info/top_level.txt'
#   adding 'fire-0.5.0.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=c76cb1ac38da5c5ac76a20e34663eedec2c17e0b656abb9c287ddaa7b3903c51
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built finetuningresearch fire
# Installing collected packages: types-PyYAML, smmap, shtab, setproctitle, sentry-sdk, python-dotenv, pycryptodome, pyarrow, fire, einops, docstring-parser, docker-pycreds, dill, multiprocess, gitdb, bitsandbytes, tyro, pydantic-settings, GitPython, accelerate, wandb, minio, datasets, trl, peft, finetuningresearch
#   changing mode of /usr/local/bin/shtab to 755
#   changing mode of /usr/local/bin/dotenv to 755
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 10.0.1
#     Uninstalling pyarrow-10.0.1:
#       Removing file or directory /usr/local/bin/plasma_store
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/pyarrow-10.0.1.dist-info/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/pyarrow/
#       Successfully uninstalled pyarrow-10.0.1
#   changing mode of /usr/local/bin/accelerate to 755
#   changing mode of /usr/local/bin/accelerate-config to 755
#   changing mode of /usr/local/bin/accelerate-estimate-memory to 755
#   changing mode of /usr/local/bin/accelerate-launch to 755
#   changing mode of /usr/local/bin/wandb to 755
#   changing mode of /usr/local/bin/wb to 755
#   changing mode of /usr/local/bin/datasets-cli to 755
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 15.0.0 which is incompatible.
# Successfully installed GitPython-3.1.41 accelerate-0.27.0 bitsandbytes-0.42.0 datasets-2.17.0 dill-0.3.8 docker-pycreds-0.4.0 docstring-parser-0.15 einops-0.7.0 finetuningresearch-0.1.0 fire-0.5.0 gitdb-4.0.11 minio-7.2.4 multiprocess-0.70.16 peft-0.8.2 pyarrow-15.0.0 pycryptodome-3.20.0 pydantic-settings-2.1.0 python-dotenv-1.0.1 sentry-sdk-1.40.3 setproctitle-1.3.3 shtab-1.6.5 smmap-5.0.1 trl-0.7.10 types-PyYAML-6.0.12.12 tyro-0.7.2 wandb-0.16.3

# %%
#export all important env variables needed for the application to work

# %%
from finetuningresearch import execute

# %%
import yaml

configs = """
project:
  name: "mmlu"

training:
  dataset:
    type: "s3"
    name: "fine-tuning-research/mmlu"
    format: "completion"
  model:
    base:
      type: "hf"
      name: "meta-llama/Llama-2-7b-hf"
    output:
      type: "hf"
      name: "rparundekar/llama2-7b-mmlu"
  trainer:
    packing: False
    max_seq_length: 512
  sft:
    per_device_train_batch_size: 24
    per_device_eval_batch_size: 24
    learning_rate: 0.0002
    lr_scheduler_type: "cosine"
    warmup_ratio: 0.1
    max_steps: 500
    gradient_accumulation_steps: 4
    gradient_checkpointing: True
    gradient_checkpointing_kwargs:
      use_reentrant: False
    logging_strategy: "steps"
    logging_steps: 5
    evaluation_strategy: "steps"
    eval_steps: 100
  peft:
    r: 64  # the rank of the LoRA matrices
    lora_alpha: 16 # the weight
    lora_dropout: 0.1 # dropout to add to the LoRA layers
    bias: "none" # add bias to the nn.Linear layers?
    task_type: "CAUSAL_LM"
    target_modules:  # the name of the layers to add LoRA
      - "q_proj"
      - "k_proj"
      - "v_proj"
      - "o_proj"
    quantized: True
"""

config = yaml.safe_load(configs)
print(config)
# Out:
# {'project': {'name': 'mmlu'}, 'training': {'dataset': {'type': 's3', 'name': 'fine-tuning-research/mmlu', 'format': 'completion'}, 'model': {'base': {'type': 'hf', 'name': 'meta-llama/Llama-2-7b-hf'}, 'output': {'type': 'hf', 'name': 'rparundekar/llama2-7b-mmlu'}}, 'trainer': {'packing': False, 'max_seq_length': 512}, 'sft': {'per_device_train_batch_size': 24, 'per_device_eval_batch_size': 24, 'learning_rate': 0.0002, 'lr_scheduler_type': 'cosine', 'warmup_ratio': 0.1, 'max_steps': 500, 'gradient_accumulation_steps': 4, 'gradient_checkpointing': True, 'gradient_checkpointing_kwargs': {'use_reentrant': False}, 'logging_strategy': 'steps', 'logging_steps': 5, 'evaluation_strategy': 'steps', 'eval_steps': 100}, 'peft': {'r': 64, 'lora_alpha': 16, 'lora_dropout': 0.1, 'bias': 'none', 'task_type': 'CAUSAL_LM', 'target_modules': ['q_proj', 'k_proj', 'v_proj', 'o_proj'], 'quantized': True}}}

# %%
execute(config)
# Out:
# Training LOCAL RANK: Unknown ...
# Training RANK: Unknown ...
# Training LOCAL WORLD SIZE: Unknown ...
# Loading model
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
